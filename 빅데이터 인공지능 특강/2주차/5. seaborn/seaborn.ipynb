# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import requests

# %%
# 그래프에 한글 사용 설정
from matplotlib import font_manager, rc
font_path = 'c:/Windows/Fonts/NGULIM.ttf'  # 폰트가 설치되어 있는 경로
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
import warnings
# 모든 경고 무시
warnings.filterwarnings('ignore')

# %%
# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# 그룹화 및 평균 계산
table = tips.groupby(["day", "time"])[["tip", "total_bill"]].mean()
table
# Out:
#                   tip  total_bill
# day  time
# Thur Lunch   2.767705   17.664754
#      Dinner  3.000000   18.780000
# Fri  Lunch   2.382857   12.845714
#      Dinner  2.940000   19.663333
# Sat  Lunch        NaN         NaN
#      Dinner  2.993103   20.441379
# Sun  Lunch        NaN         NaN
#      Dinner  3.255132   21.410000

# %%
table = tips.groupby(['day', 'time']).agg({'tip' : 'mean', 'total_bill' : 'sum'})
table
# Out:
#                   tip  total_bill
# day  time
# Thur Lunch   2.767705     1077.55
#      Dinner  3.000000       18.78
# Fri  Lunch   2.382857       89.92
#      Dinner  2.940000      235.96
# Sat  Lunch        NaN        0.00
#      Dinner  2.993103     1778.40
# Sun  Lunch        NaN        0.00
#      Dinner  3.255132     1627.16

# %%
# 결측치 0으로 채우기, 소숫점 첫째자리
table.fillna(0).round(1)
# Out:
#              tip  total_bill
# day  time
# Thur Lunch   2.8      1077.6
#      Dinner  3.0        18.8
# Fri  Lunch   2.4        89.9
#      Dinner  2.9       236.0
# Sat  Lunch   0.0         0.0
#      Dinner  3.0      1778.4
# Sun  Lunch   0.0         0.0
#      Dinner  3.3      1627.2

# %%
table.fillna(0).astype(int).style.background_gradient()
# Out:
# <style type="text/css">
# #T_324a7_row0_col0, #T_324a7_row2_col0, #T_324a7_row3_col0, #T_324a7_row5_col0 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_324a7_row0_col1 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_324a7_row1_col0, #T_324a7_row5_col1, #T_324a7_row7_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_324a7_row1_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_324a7_row2_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_324a7_row3_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_324a7_row4_col0, #T_324a7_row4_col1, #T_324a7_row6_col0, #T_324a7_row6_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_324a7_row7_col1 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_324a7">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_324a7_level0_col0" class="col_heading level0 col0" >tip</th>
#       <th id="T_324a7_level0_col1" class="col_heading level0 col1" >total_bill</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >day</th>
#       <th class="index_name level1" >time</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_324a7_level0_row0" class="row_heading level0 row0" rowspan="2">Thur</th>
#       <th id="T_324a7_level1_row0" class="row_heading level1 row0" >Lunch</th>
#       <td id="T_324a7_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_324a7_row0_col1" class="data row0 col1" >1077</td>
#     </tr>
#     <tr>
#       <th id="T_324a7_level1_row1" class="row_heading level1 row1" >Dinner</th>
#       <td id="T_324a7_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_324a7_row1_col1" class="data row1 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_324a7_level0_row2" class="row_heading level0 row2" rowspan="2">Fri</th>
#       <th id="T_324a7_level1_row2" class="row_heading level1 row2" >Lunch</th>
#       <td id="T_324a7_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_324a7_row2_col1" class="data row2 col1" >89</td>
#     </tr>
#     <tr>
#       <th id="T_324a7_level1_row3" class="row_heading level1 row3" >Dinner</th>
#       <td id="T_324a7_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_324a7_row3_col1" class="data row3 col1" >235</td>
#     </tr>
#     <tr>
#       <th id="T_324a7_level0_row4" class="row_heading level0 row4" rowspan="2">Sat</th>
#       <th id="T_324a7_level1_row4" class="row_heading level1 row4" >Lunch</th>
#       <td id="T_324a7_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_324a7_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_324a7_level1_row5" class="row_heading level1 row5" >Dinner</th>
#       <td id="T_324a7_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_324a7_row5_col1" class="data row5 col1" >1778</td>
#     </tr>
#     <tr>
#       <th id="T_324a7_level0_row6" class="row_heading level0 row6" rowspan="2">Sun</th>
#       <th id="T_324a7_level1_row6" class="row_heading level1 row6" >Lunch</th>
#       <td id="T_324a7_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_324a7_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_324a7_level1_row7" class="row_heading level1 row7" >Dinner</th>
#       <td id="T_324a7_row7_col0" class="data row7 col0" >3</td>
#       <td id="T_324a7_row7_col1" class="data row7 col1" >1627</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2)
fig.set_size_inches(15, 10)
sns.barplot(data = tips, x="day", y="tip", ax=ax1, palette="Set2")
sns.barplot(data = tips, x="sex", y="tip", ax=ax2, palette="Set1")
sns.barplot(data = tips, x="time", y="tip", ax=ax3, palette="Pastel1")
sns.barplot(data = tips, x="smoker", y="tip", ax=ax4, palette="Dark2")

ax1.set(title="요일별 tip")
ax2.set(title="성별 tip")  
ax3.set(title="시간별 tip")
ax4.set(title="흡연별 tip")
# Out:
# [Text(0.5, 1.0, '흡연별 tip')]

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2)
fig.set_size_inches(15, 10)
sns.barplot(data = tips, x="day", y="total_bill", ax=ax1, palette="Set2")
sns.barplot(data = tips, x="sex", y="total_bill", ax=ax2, palette="Set1")
sns.barplot(data = tips, x="time", y="total_bill", ax=ax3, palette="Pastel1")
sns.barplot(data = tips, x="smoker", y="total_bill", ax=ax4, palette="Dark2")

ax1.set(title="요일별 tip")
ax2.set(title="성별 tip")  
ax3.set(title="시간별 tip")
ax4.set(title="흡연별 tip")
# Out:
# [Text(0.5, 1.0, '흡연별 tip')]
